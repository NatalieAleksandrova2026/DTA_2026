# %% [markdown]
# <a href="https://colab.research.google.com/github/NatalieAleksandrova2026/DTA_2026/blob/main/Intro_to_moduls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Знакомство с модулями Python
#
# > Добавить блок с цита
