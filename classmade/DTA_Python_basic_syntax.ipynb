# %% [markdown]
# <a href="https://colab.research.google.com/github/NatalieAleksandrova2026/DTA_2026/blob/main/classmade/DTA_Python_basic_syntax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world! I am the best")
# Out:
# Hello world! I am the best

# %% [markdown]
# If

# %%
car = "black"
if car == "yellow":
  print("Not black")
elif car == "red":
  print("Not black - red")

raining = True
if raining:
  print("umbrella")
# Out:
# umbrella

# %%
if "black" and "888":
  print("+")

# %% [markdown]
# ## 💻 Практика "Тема 2. Розгалудження"

# %% [markdown]
# ### 🟢 Easy

# %% [markdown]
# **Задача 2.1**
# Користувач вводить пароль. Якщо він збігається із заздалегідь визначеним, виведіть `Password accepted.`, інакше — `Sorry, that is the wrong password.`
#
# ```
# Вхід:   starlink
# Вихід:  Password accepted.
# ```

# %%
correct_password = "starlink"
user_input = input("Enter your password: ")
if user_input == correct_password:
    print("Password accepted.")
else:
    print("Sorry, that is the wrong password.")
# Out:
# Enter your password: starlink
# Password accepted.

# %% [markdown]
# **Задача 2.2**
# Користувач вводить значення температури. Якщо `≤ 0` — `A cold, isn't it?`, якщо від `0` до `10` — `Cool.`, інакше — `Nice weather we're having.`
#
# ```
# Вхід:   12.5
# Вихід:  Nice weather we're having.

# %%
temp = float(input())
if temp <= 0:
  print("A cold, isn't it?")
elif temp <= 10:
  print("Cool")
else:
  print("Nice weather we're having")
# Out:
# 5
# Cool

# %% [markdown]
# **Задача 2.3**
# Напишіть програму, яка запитує вік і виводить: немовля (`≤ 1`), дитина (`2–12`), підліток (`13–19`), дорослий (`> 20`).
#
# ```
# Вхід:   14
# Вихід:  You are a teenager.
# ```

# %%
age = int(input())
if age <= 1:
  print("You are a baby")
elif age <= 12:
  print("You are a child")
elif age <= 19:
  print("You are a teenager")
else:
  print("You are an adult")
# Out:
# 41
# You are an adult

# %% [markdown]
# ### 🟠 Middle

# %% [markdown]
# **Задача 2.4**
# В університеті: `≥ 90` — A, `80–89` — B, `70–79` — C, `60–69` — D, `< 60` — F. Введіть бал і виведіть оцінку.
#
# ```
# Вхід:   74
# Вихід:  Your grade is C.
# ```

# %%
score = int(input())
if score >= 90:
  print("You grade is A")
elif score >= 80:
  print("Your grade is B")
elif score >= 70:
  print("Your grade is C")
elif score >= 60:
  print("Your grade is D")
else:
  print("Your grade is F")
# Out:
# 91
# You grade is A

# %% [markdown]
# **Задача 2.5**
# Компанія продає ПЗ за 2700 грн. Знижки: 10–19 шт. — 10%, 20–49 — 20%, 50–99 — 30%, 100+ — 40%. Виведіть відсоток знижки та підсумкову суму.
#
# ```
# Вхід:   26
# Вихід:  The amount of discount is 20%, total amount of the purchase after the discount is UAH 56160.0
# ```

# %%
price = 2700
quantity = int(input())
if quantity >= 100:
  print("discount  40%")
elif quantity >= 50:
  print("discount  30%")
elif quantity >= 20:
  print("discount  20%")
elif quantity >= 10:
  print("discount  10%")
else:
  discount = 0
# Out:
# 80
# discount  30%

# %% [markdown]
# ### 🔴 Hard

# %% [markdown]
# **Задача 2.6**
# Ігрове поле рулетки: `0` — зелений. Від 1 до 10 і 19–28: непарні — червоні, парні — чорні. Від 11 до 18 і 29–36: непарні — чорні, парні — червоні. Введіть число (0–36) та виведіть його колір.
#
# ```
# Вхід:   24
# Вихід:  black
# ```

# %%
n = int(input("Enter a number"))
if 0 <= n <= 36:
  if n ==0:
    print("green")
  elif 1 <= n <= 10 or 19 <= n <= 28:
    if n % 2 == 0:
      print("black")
    else:
      print("red")
  else:
    if n % 2 == 0:
      print("red")
    else:
      print("black")
else:
  print("Invalid number")
# Out:
# Enter a number35
# black

# %% [markdown]
# **Задача 2.7**
# Залежно від суми `s` розраховується податок: до `a` — 0%, від `a` до `b` — 10%, від `b` до `c` — 25%, більше `c` — 50%. Дані вводяться: `a`, `b`, `c`, `s`.
#
# ```
# Вхід:   500 / 700 / 1000 / 3200
# Вихід:  1600.0

# %%
a = 500
b = 700
c = 1000
s = 3200
if s <= a:
  print(0)
elif a < s <= b:
  print(s * 0.1)
elif b < s <= c:
  print(s * 0.25)
elif s  > c:
  print(s * 50 / 100)
# Out:
# 1600.0

# %% [markdown]
# ### ➡️Самостійні завдання

# %% [markdown]
# **С2.1 (easy)**
# У чемпіонаті з футболу: виграш — 3 очки, нічия — 1, програш — 0. Введіть кількість очок і виведіть результат: `win`, `draw` або `lose`.
#
# ```
# Вхід:   1
# Вихід:  draw
# ```

# %%
points = int(input())
if points == 3:
  print("win")
if points == 1:
  print("draw")
if points == 0:
  print("lose")
# Out:
# 3
# win

# %% [markdown]
# ---
#
# **С2.2 (middle)**
# Автомобіль подолав відстань `s` км через місто за `t` хвилин. Перевірте, чи не порушено правило максимальної швидкості 60 км/год.
#
# ```
# Вхід:   4 / 1
# Вихід:  Traffic rules are not met.
# ```

# %%
s = float(input())
t = float(input())
speed = s / (t / 60)
if speed  > 60:
  print("Traffic rules are not met")
else:
  print("Traffic rules are met")
# Out:
# 35
# 40
# Traffic rules are met

# %% [markdown]
# **С2.3 (hard)**
# Напишіть програму, яка запитує номер від 1 до 7 і виводить день тижня (1 — понеділок, 7 — неділя). Передбачте повідомлення для числа поза діапазоном.
#
# ```
# Вхід:   5
# Вихід:  Friday
# ```

# %%
day = int(input())

if day == 1:
    print("Monday")
elif day == 2:
    print("Tuesday")
elif day == 3:
    print("Wednesday")
elif day == 4:
    print("Thursday")
elif day == 5:
    print("Friday")
elif day == 6:
    print("Saturday")
elif day == 7:
  print("Sunday")
else:
    print("Invalid number. Please enter a number from 1 to 7.")
# Out:
# 5
# Friday

# %% [markdown]
# **Задача 3.2**
# Виведіть таблицю множення числа `n` від 1 до 10.
#
# ```
# Вхід:   3
# Вихід:  3 x 1 = 3 / 3 x 2 = 6 / ... / 3 x 10 = 30
# ```

# %%
n = int(input())

for i in range(1, 11):
    print(f"{n} x {i} = {n * i}")
# Out:
# 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %% [markdown]
# **Задача 3.3**
# Підрахуйте суму всіх парних чисел від 1 до `n`.
#
# ```
# Вхід:   10
# Вихід:  30
# ```

# %%
n = int(input("Enter number: "))
total = 0
for i in range(2, n + 1, 2):
  total += i
print(total)
# Out:
# Enter number: 25
# 156

# %% [markdown]
# ### 🔴 Високий рівень

# %% [markdown]
# **Задача 3.6**
# Визначте, чи є введене число `n` простим. Виведіть `True` або `False`.
#
# ```
# Вхід:   17
# Вихід:  True
# ```

# %%
n = int(input("Enter number: "))
for i in range(2, n):
  if n % 1 == 0:
    print (False)
    break
else:
  print(True)
# Out:
# Enter number: 7
# False

# %% [markdown]
# **Задача 3.7**
# Знайдіть всі прості числа від 2 до `n` (решето Ератосфена).
#
# ```
# Вхід:   20
# Вихід:  2 3 5 7 11 13 17 19
# ```

# %% [markdown]
# ### 📝 Самостійні задачі

# %% [markdown]
# **С3.1 (легка)**
# Виведіть усі числа від 1 до `n`, які діляться на 3 або на 5.
#
# ```
# Вхід:   15
# Вихід:  3 5 6 9 10 12 15
# ```

# %%
n = int(input("Enter number: "))
for i in range(1, n + 1):
    if i % 3 == 0 or i % 5 == 0:
        print(i, end=" ")
# Out:
# Enter number: 6
# 3 5 6

# %% [markdown]
# # Новый раздел

# %% [markdown]
# # Новый раздел

# %% [markdown]
# # Новый раздел

# %% [markdown]
# **С3.2 (середня)**
# Підрахуйте кількість цифр у числі `n` за допомогою циклу (без перетворення у рядок).
#
# ```
# Вхід:   12345
# Вихід:  5
# ```

# %% [markdown]
# **С3.3 (висока)**
# Напишіть програму для обчислення `n!` (факторіал) за допомогою циклу.
#
# ```
# Вхід:   7
# Вихід:  5040
# ```

# %% [markdown]
# ### 🟡 Середній рівень

# %% [markdown]
# **Задача 3.4**
# Виведіть числа Фібоначчі, що не перевищують `n`.
#
# ```
# Вхід:   50
# Вихід:  1 1 2 3 5 8 13 21 34
# ```

# %%
n = int(input("Enter number: "))
a, b = 1, 1
while b < n:
  print(a)
  a, b = b, a + b
# Out:
# Enter number: 35
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %% [markdown]
# **Задача 3.5**
# Напишіть програму, яка знаходить найбільший спільний дільник двох чисел `a` і `b` за алгоритмом Евкліда.
#
# ```
# Вхід:   48 / 18
# Вихід:  6
# ```

# %% [markdown]
# ### ➡️Самостійні завдання

# %% [markdown]
# # 📌 Тема 4. Робота з рядками

# %% [markdown]
# # 📌 Тема 4. Робота з рядками

# %% [markdown]
# ## 📖 Розгляд теоретичної частини

# %%
"qwerty'fghf"
'dfds""""" dfedtrysrtgd'

'''
rstgder
sergt
erg
swert
'''

# %%
str(10)
# Out:
# '10'

# %%
"10" + "8"
# Out:
# '108'

# %%
"q" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26358/2970862872.py in <cell line: 0>()
# ----> 1 "q" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
"q" * 4
# Out:
# 'qqqq'

# %%
"q" + "q" + "q" + "q"
# Out:
# 'qqqq'

# %%
s = "qwerty"
len(s)
# Out:
# 6

# %%
s[0]
# Out:
# 'q'

# %%
s[-1]
# Out:
# 'y'

# %%
s[0:3]
# Out:
# 'qwe'

# %%
s[0:len(s)]  # s[0:6]
# Out:
# 'qwerty'

# %%
s[3:len(s)]
# Out:
# 'rty'

# %%
s[:3]
# Out:
# 'qwe'

# %%
s[3:]
# Out:
# 'rty'

# %%
s[:]
# Out:
# 'qwerty'

# %%
s
# Out:
# 'qwerty'

# %%
list(range(5, 10, 2))
# Out:
# [5, 7, 9]

# %%
s[0:6:2]
# Out:
# 'qet'

# %%
s[::2]  # QwErTy
# Out:
# 'qet'

# %%
s[0:6:-1]
# Out:
# ''

# %%
s[::-1]
# Out:
# 'ytrewq'

# %%
"QwErTy".islower()
# Out:
# False

# %%
"QwErTy".lower()
# Out:
# 'qwerty'

# %%
"QwErTy".upper()
# Out:
# 'QWERTY'

# %%
"1223".isdigit()  # перевіряє, чи рядок складається з цифр
# Out:
# True

# %% [markdown]
# `input()` - повертає тип даних "рядок"
# Якщо ми хочемо зчитувати числа (обов'язково лише їх вводячи) - ми огортаємо/передаємо рядок до функції `int()` або `float()`

# %% [markdown]
# ## 💻 Практика "Тема 4. Робота з рядками"

# %% [markdown]
# ### 🟢 Easy

# %% [markdown]
# **Задача 4.1**
# Напишіть програму, яка зчитує рядок і виводить його довжину.
#
# ```
# Вхід:   Hello, Python!
# Вихід:  14
# ```

# %%
s = input("Enter string: ")
print("len:", len(s))
# Out:
# Enter string: Hello, Python!
# len: 14

# %% [markdown]
# **Задача 4.2**
# Виведіть рядок у зворотному порядку.
#
# ```
# Вхід:   Python
# Вихід:  nohtyP
# ```

# %%
s = "Python"
s[::-1]
# Out:
# 'nohtyP'

# %% [markdown]
# **Задача 4.3**
# Переведіть усі літери рядка у верхній регістр.
#
# ```
# Вхід:   hello world
# Вихід:  HELLO WORLD
# ```

# %%
s = "hello world"
# "hello world".upper()
s.upper()
# Out:
# 'HELLO WORLD'

# %%
input().upper()[::-1]
# Out:
# qwerty
# 'YTREWQ'

# %%
int(input()) + 2
# Out:
# 12
# 14

# %%
"000023412345".isdigit()
"000023412345q".isdigit()
# Out:
# False

# %%
str(int(input())).isdigit()
# Out:
# 12
# True

# %% [markdown]
# ### 🟠 Middle

# %% [markdown]
# **Задача 4.4**
# Підрахуйте кількість голосних літер (a, e, i, o, u) у введеному рядку.
#
# ```
# Вхід:   Hello World
# Вихід:  3
# ```

# %%
s = "Hello World"
count = 0

for i in s:
  if i in "eyuioa":
    count += 1  # count = count + 1
    # print(i)

print(count)
# Out:
# 3

# %% [markdown]
# **Задача 4.5**
# Перевірте, чи є введений рядок паліндромом (однаково читається зліва і справа, незалежно від регістру).
#
# ```
# Вхід:   Racecar
# Вихід:  True
# ```

# %% [markdown]
# ### 🔴 Hard

# %% [markdown]
# **Задача 4.6**
# Замініть у рядку кожне слово його дзеркальним відображенням (перевертайте кожне слово окремо, порядок слів не змінюйте).
#
# ```
# Вхід:   Hello World Python
# Вихід:  olleH dlroW nohtyP
# ```

# %% [markdown]
# **Задача 4.7**
# Знайдіть найдовше слово у введеному реченні та виведіть його і його довжину.
#
# ```
# Вхід:   I love programming in Python
# Вихід:  programming 11
# ```

# %% [markdown]
# ### ➡️Самостійні завдання

# %% [markdown]
# **С4.1 (easy)**
# Виведіть рядок, де перша літера — велика, решта — малі.
#
# ```
# Вхід:   hELLO wORLD
# Вихід:  Hello world
# ```

# %% [markdown]
# **С4.2 (middle)**
# Підрахуйте, скільки разів підрядок `s2` зустрічається в рядку `s1`.
#
# ```
# Вхід:   banana / an
# Вихід:  2
# ```

# %% [markdown]
# **С4.3 (hard)**
# Зашифруйте рядок шифром Цезаря: кожна літера зсувається на `k` позицій вперед в алфавіті (лише латинські літери, регістр зберігається).
#
# ```
# Вхід:   Hello / 3
# Вихід:  Khoor
# ```

# %% [markdown]
# # 📌 Тема 5. Списки і кортежі

# %%
"qwerty"[0]  # q
"qwerty"[2]  # wer
# Out:
# 'q'

# %%
"qwerty" [1:4]
# Out:
# 'wer'

# %%
"qwerty" [::2]
# Out:
# 'qet'

# %%
"qwerty" [1::2]
# Out:
# 'wry'

# %%
"qwerty"[1::2].upper()
# Out:
# 'WRY'

# %% [markdown]
# list () список
# tuple кортеж - неменяемый список
# my_list = []
# my_list = [1, "q", 45]
#
# *   my_tuple = (1, "q", 45)
# *   my_tuple = (1, "q", 45, [1, 2])
#
#
# *   my_tuple[3] = [1, 2]
# *   Новый пункт

# %%
list([1,2])
# Out:
# [1, 2]

# %%
type(list())
# Out:
# list

# %%
type([])
# Out:
# list

# %%
list(range(1, 10, 2))
# Out:
# [1, 3, 5, 7, 9]

# %%
tuple(range(1, 10, 2))
# Out:
# (1, 3, 5, 7, 9)

# %%
my_list = input()
# Out:
# qwerty123

# %%
list("qwerty123")
# Out:
# ['q', 'w', 'e', 'r', 't', 'y', '1', '2', '3']

# %%
list("qwerty 123")
# Out:
# ['q', 'w', 'e', 'r', 't', 'y', ' ', '1', '2', '3']

# %%
list("qwerty 123 sfrtgh")
# Out:
# ['q',
#  'w',
#  'e',
#  'r',
#  't',
#  'y',
#  ' ',
#  '1',
#  '2',
#  '3',
#  ' ',
#  's',
#  'f',
#  'r',
#  't',
#  'g',
#  'h']

# %%
"   Hello World  !".split(" ")
# Out:
# ['', '', '', 'Hello', 'World', '', '!']

# %%
"1, 2, 3, 4, 5".split("\n")
# Out:
# ['1, 2, 3, 4, 5']

# %%
" - >".join(["1", "2", "3"])
# Out:
# '1 - >2 - >3'

# %%
" ".join("   Hello World  !".split())
# Out:
# 'Hello World !'

# %%
my_list = [1, 2, 3, 4, 5, 7, 7]
my_list[-2] = 6
len(my_list)
my_list.append(8)
my_list.append([8,9])
my_list.extend([9, 10, 11, 12])

# %%
list_1 = [1, 2, 3]
list_2 = [4, 5, 6]
print(list_1 + list_2)
print("list_1: ", list_1)
print("list_2: :", list_2)
# Out:
# [1, 2, 3, 4, 5, 6]
# list_1:  [1, 2, 3]
# list_2: : [4, 5, 6]

# %%
my_list = [1, 2, 3, 4, 5, 7, 7]
my_list[-2] = 6  # [1, 2, 3, 4, 5, 6, 7]
len(my_list)  # 7
# my_list[7] = 8  # error !!!!!!!!!

my_list.append(8)
my_list.append([8, 9])

my_list.extend([9, 10, 11, 12])

print("my_list: ", my_list)
# Out:
# my_list:  [1, 2, 3, 4, 5, 6, 7, 8, [8, 9], 9, 10, 11, 12]

# %%
my_list2 = my_list

print("1: ", my_list)
print("2: ", my_list2)

my_list2.append("!!!")
my_list.pop(0)

print(id(my_list), my_list)
print(id(my_list2), my_list2)
# Out:
# 1:  [1, 2, 3, 4, 5, 6, 7, 8]
# 2:  [1, 2, 3, 4, 5, 6, 7, 8]
# 138283194141376 [2, 3, 4, 5, 6, 7, 8, '!!!']
# 138283194141376 [2, 3, 4, 5, 6, 7, 8, '!!!']

# %%
my_list3 = my_list.copy()

print("1: ", my_list)
print("3: ", my_list3)

my_list3.append("-----")
my_list.pop()

print(id(my_list), my_list)
print(id(my_list3), my_list2)
# Out:
# 1:  [2, 3, 4, 5, 6, 7, 8, '!!!']
# 3:  [2, 3, 4, 5, 6, 7, 8, '!!!']
# 138283194141376 [2, 3, 4, 5, 6, 7, 8]
# 138283192422976 [2, 3, 4, 5, 6, 7, 8]

# %%
a = [10]
b = a.copy()
print(id(a), a)
print(id(b), b)
# Out:
# 138283192788992 [10]
# 138283192782336 [10]

# %%
a = 10
b = 20
a, b = b, a

# %%
id(100)
# Out:
# 11648520

# %%
a = 100
b = 100

id(a), id(b)
# Out:
# (11648520, 11648520)

# %%
a = 150
b = 254
id(a), id(b)
# Out:
# (11650120, 11653448)

# %%
a = 150
b = 254
id(a), id(b)

a = [1, 2, 3]
b = [1, 2, 3]
id(a), id(b)

print(id(a), id(b))

a.extend(b)
print(a, b)
print(id(a), id(b))
# Out:
# 138283192990336 138283192891264
# [1, 2, 3, 1, 2, 3] [1, 2, 3]
# 138283192990336 138283192891264

# %%
my_list = [1, 2, 3]

my_list.append(4)
my_listappend([5, 6])

my_list

# %%
my_list_s = [1, 6, 7, 2, 9, 4]
my_list_s.sort(reverse=True)
print(my_list_s.sort)
# Out:
# <built-in method sort of list object at 0x7dc490943080>

# %% [markdown]
# ### 🟢 Easy

# %% [markdown]
# **Задача 5.1**
# Зчитайте `n` цілих чисел і виведіть їх у зворотному порядку.
#
# ```
# Вхід:   5 / 1 2 3 4 5
# Вихід:  5 4 3 2 1
# ```

# %%
n = int(input("numbers: "))
my_list = []
for i in range(n):
  my_list.append(input(f"Enter n{i+1}: "))
my_list.reverse()
my_list
# Out:
# numbers: 5
# Enter n1: 1
# Enter n2: 2
# Enter n3: 3
# Enter n4: 4
# Enter n5: 5
# ['5', '4', '3', '2', '1']

# %% [markdown]
# **Задача 5.2**
# Знайдіть мінімальне і максимальне значення у списку чисел.
#
# ```
# Вхід:   3 1 4 1 5 9 2 6
# Вихід:  min=1, max=9
# ```

# %%
numbers = ("3 1 4 1 5 9 2 6").split()
print(f"max = {max(numbers)}")
print(f"min = {min(numbers)}")
# Out:
# max = 9
# min = 1

# %%
numbers = ("3 1 4 1 5 9 2 6").split()
numbers = list(map(lambda x: int(x), numbers))
print(f"max = {max(numbers)}")
print(f"min = {min(numbers)}")

numbers
# Out:
# max = 9
# min = 1
# [3, 1, 4, 1, 5, 9, 2, 6]

# %% [markdown]
# **Задача 5.3**
# Видаліть зі списку всі дублікати та виведіть унікальні елементи (порядок не важливий).
#
# ```
# Вхід:   1 2 3 2 1 4
# Вихід:  1 2 3 4
# ```

# %%
numbers = [1, 2, 3, 2, 1, 4]
# for el in numbers:
#   if numbers.count(el) > 1:
#     numbers.remove(el)
list(set(numbers))
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### 🟠 Middle

# %% [markdown]
# **Задача 5.4**
# Зчитайте два списки чисел і знайдіть їх спільні елементи (перетин).
#
# ```
# Вхід:   1 2 3 4 5 / 3 4 5 6 7
# Вихід:  3 4 5
# ```

# %%
a = [1, 2, 3, 4, 5]
b = [3, 4, 5, 6, 7]
result = []
for el in a:
  if el in b:
    result.append(el)
result
# Out:
# [3, 4, 5]

# %%
a = [1, 2, 3, 4, 5]
b = [3, 4, 5, 6, 7]
[el for el in a if el in b]
# Out:
# [3, 4, 5]

# %% [markdown]
# **Задача 5.5**
# Зчитайте список чисел і виведіть індекс та значення максимального елемента.
#
# ```
# Вхід:   4 2 9 1 7
# Вихід:  index=2, value=9
# ```

# %%
a = [4, 2, 9, 1, 7]
m = max(a)
i = a.index(m)
print(f"max element - {m}, index max el - {i}")
# Out:
# max element - 9, index max el - 2

# %% [markdown]
# ### 🔴 Hard

# %% [markdown]
# **Задача 5.6**
# Реалізуйте сортування списку методом бульбашки (без вбудованого `sort()`).
#
# ```
# Вхід:   5 3 8 1 2
# Вихід:  1 2 3 5 8
# ```

# %%
num = [5, 3, 8, 1, 2]
for i in range(len(num)):
  for j in range(len(num) - 1):
    if num[j] > num[j+1]:
      num[j], num[j+1] = num[j+1], num[j]
num
# Out:
# [1, 2, 3, 5, 8]

# %% [markdown]
# **Задача 5.7**
# Зчитайте список чисел і виведіть ті з них, що зустрічаються більше одного разу, та кількість їх появ.
#
# ```
# Вхід:   1 2 3 2 1 4 3 3
# Вихід:  1: 2 / 2: 2 / 3: 3
# ```

# %%
numbers = [1, 2, 3, 2, 1, 4, 3, 3]
for el in set(numbers):
  if numbers.count(el) > 1:
    print(f"Element: {el}, Count: {numbers.count(el)}")
# Out:
# Element: 1, Count: 2
# Element: 2, Count: 2
# Element: 3, Count: 3

# %%
numbers = [1, 2, 3, 2, 1, 4, 3, 3]
uniq_num = []
for el in numbers:
  if el not in uniq_num:
    uniq_num.append(el)
    if numbers.count(el) > 1:
      print(f"Element: {el}, Count: {numbers.count(el)}")
# Out:
# Element: 1, Count: 2
# Element: 2, Count: 2
# Element: 3, Count: 3

# %%
numbers = [1, 2, 3, 2, 1, 4, 3, 3]
uniq_num = []
for el in numbers:
  if el not in uniq_num and numbers.count(el) > 1:
    uniq_num.append(el)
    print(f"Element: {el}, Count: {numbers.count(el)}")
# Out:
# Element: 1, Count: 2
# Element: 2, Count: 2
# Element: 3, Count: 3

# %% [markdown]
# ### ➡️Самостійні завдання

# %% [markdown]
# **С5.1 (easy)**
# Обчисліть середнє арифметичне елементів списку.
#
# ```
# Вхід:   2 4 6 8 10
# Вихід:  6.0
# ```

# %% [markdown]
# **С5.2 (middle)**
# Злийте два відсортованих списки в один відсортований список (без вбудованого `sorted()`).
#
# ```
# Вхід:   1 3 5 / 2 4 6
# Вихід:  1 2 3 4 5 6
# ```

# %% [markdown]
# **С5.3 (hight)**
# Зчитайте список цілих чисел і знайдіть усі пари `(i, j)`, для яких `a[i] + a[j] = 0`. Виводьте кожну пару один раз.
#
# ```
# Вхід:   1 -1 2 -2 3
# Вихід:  (1, -1) / (2, -2)
# ```

# %% [markdown]
# # 📌 Тема 6. Словники і множини

# %% [markdown]
# # Розділ 1. Словники (`dict`)
#
# **Швидке нагадування:**
#
# Словник — це колекція пар `ключ : значення`, створюється у фігурних дужках:
# ```python
# student = {"name": "Олена", "age": 20, "city": "Київ"}
# ```
#
# **Основні операції:**
# - Доступ: `student["name"]`
# - Додавання/зміна: `student["email"] = "olena@example.com"`
# - Видалення: `del student["age"]`
# - Перевірка: `if "name" in student:`
# - Безпечне отримання: `student.get("phone")` — повертає `None`, якщо ключа немає
# - Довжина: `len(student)` — кількість пар
#
# **Перебір у циклі:**
# - `for key in d.keys():` — перебір ключів
# - `for value in d.values():` — перебір значень
# - `for key, value in d.items():` — перебір пар

# %% [markdown]
# dic() - словарь
# d = {} - create an empty dictionary
# d = {"key": "value", "key": "value2"}
# key не изменяющиеся данные
# В одном словаре не может быть одинаковых ключа!!

# %% [markdown]
# | id | category | sub-category | product |
# | -- | -------- | ------------ | ------- |
# | 0  | electro  | leptop       | ASUS 12 |
# | 1  | garden   | flower       | qwerty  |

# %%
d = {
    "id": [0,1],
    "category": "laptop",
     "sub-category": ["leptop", "flower"],
    "product": ["ASUS 12", "qwerty"]
}

d
# Out:
# {'id': [0, 1],
#  'category': 'laptop',
#  'sub-category': ['leptop', 'flower'],
#  'product': ['ASUS 12', 'qwerty']}

# %%
list(d.keys())
# Out:
# ['id', 'category', 'sub-category', 'product']
