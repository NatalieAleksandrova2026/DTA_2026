# %% [markdown]
# <a href="https://colab.research.google.com/github/NatalieAleksandrova2026/DTA_2026/blob/main/Homework/pandas_viz_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas + Matplotlib: практикум на 80 завдань
#
# **Рівень:** середній (pandas) + початковий (matplotlib)
#
# ---
#
# Цей зошит містить **80 завдань**:
# - **50 завдань pandas** — поглиблюємо те, що вивчили, додаємо `loc`/`iloc`, `pivot_table`, складніший `groupby`
# - **30 завдань візуалізації** — pandas `.plot()` + основи matplotlib з кольорами, стилями та легендами
#
# ## Дані
# Працюємо з даними стрімінгового сервісу. Два файли:
#
# **`streaming_subscribers.csv`** (600 рядків) — підписники сервісу:
#
# | Стовпець | Опис |
# |---|---|
# | `subscriber_id` | Унікальний номер підписника |
# | `age` | Вік |
# | `gender` | Стать (Ч / Ж) |
# | `country` | Країна (Україна, Польща, Німеччина, Чехія, Литва, Іспанія) |
# | `plan` | Тариф (Basic / Standard / Premium / Family) |
# | `monthly_fee` | Місячна плата (грн) |
# | `join_date` | Дата реєстрації |
# | `is_active` | Активний абонемент (Так / Ні) |
#
# **`streaming_sessions.csv`** (5000 рядків) — сеанси перегляду:
#
# | Стовпець | Опис |
# |---|---|
# | `session_id` | Унікальний номер сеансу |
# | `subscriber_id` | ID підписника (зв'язок з першою таблицею) |
# | `date` | Дата перегляду |
# | `genre` | Жанр |
# | `device` | Пристрій (Smart TV / Laptop / Mobile / Tablet) |
# | `duration_min` | Тривалість перегляду в хвилинах |
# | `rating` | Оцінка користувача (1-5) |
#
# ## Як працювати
# - У кожній комірці є коментар з номером завдання — пишіть код під ним
# - Запускайте кожну комірку (Shift + Enter), щоб бачити результат
# - Якщо забули синтаксис — користуйтесь шпаргалкою з pandas та новою шпаргалкою matplotlib
# - Не бійтесь експериментувати!
#
# ---

# %% [markdown]
# ## Підготовка
#
# Запустіть цю комірку — вона завантажує бібліотеки та дані. Усі завдання використовують змінні `subs` (підписники) та `sess` (сеанси).

# %%
import pandas as pd
import matplotlib.pyplot as plt

subs = pd.read_csv("streaming_subscribers.csv")
sess = pd.read_csv("streaming_sessions.csv")

# Перетворюємо дати на справжній формат
subs["join_date"] = pd.to_datetime(subs["join_date"])
sess["date"] = pd.to_datetime(sess["date"])

print("Підписники:", subs.shape)
print("Сеанси:", sess.shape)
subs.head()
# Out:
# Підписники: (600, 8)
# Сеанси: (5000, 7)
#    subscriber_id  age gender  country      plan  monthly_fee  join_date  \
# 0           1001   19      Ч  Україна   Premium          329 2023-02-27
# 1           1002   40      Ж   Польща  Standard          219 2022-03-05
# 2           1003   60      Ч  Україна     Basic          149 2023-02-20
# 3           1004   36      Ч    Чехія     Basic          149 2022-02-22
# 4           1005   34      Ж  Іспанія  Standard          219 2023-08-27
#
#   is_active
# 0        Ні
# 1       Так
# 2       Так
# 3       Так
# 4       Так

# %% [markdown]
# ---
#
# # Частина 1. Pandas (50 завдань)
#
# Розділи:
# 1. Розминка — повторення (1-8)
# 2. `loc` та `iloc` — вибірка за позиціями та мітками (9-18)
# 3. Складніший groupby (19-28)
# 4. `pivot_table` — зведені таблиці (29-36)
# 5. Робота з датами + обчислення (37-44)
# 6. Комбіновані завдання (45-50)

# %% [markdown]
# ## Розділ 1.1. Розминка (завдання 1-8)
#
# Швидке повторення того, що вже знаємо.

# %% [markdown]
# **Завдання 1.** Виведіть перші 10 рядків таблиці `sess`.

# %%
# Завдання 1:
sess.head(10)
# Out:
#    session_id  subscriber_id       date           genre    device  \
# 0       51573           1166 2024-04-11        Анімація    Mobile
# 1       50017           1429 2024-06-25       Романтика    Mobile
# 2       50861           1404 2024-07-05         Бойовик  Smart TV
# 3       54446           1520 2024-07-01          Серіал    Laptop
# 4       51561           1052 2024-06-13         Бойовик    Laptop
# 5       51938           1078 2024-08-27  Документальний    Mobile
# 6       52050           1343 2024-02-26         Бойовик    Tablet
# 7       54963           1444 2024-08-04          Серіал  Smart TV
# 8       50908           1521 2024-04-02           Драма  Smart TV
# 9       51976           1555 2024-04-11           Драма    Mobile
#
#    duration_min  rating
# 0            72       1
# 1            53       5
# 2            49       5
# 3            66       3
# 4            81       5
# 5            60       4
# 6            86       3
# 7            56       4
# 8            68       4
# 9            84       5

# %% [markdown]
# **Завдання 2.** Скільки всього підписників у даних? А сеансів?
#
# > 💡 Атрибут `shape[0]` або функція `len()`.

# %%
# Завдання 2:
subs.shape[0]
# Out:
# 600

# %%
len(sess)
# Out:
# 5000

# %% [markdown]
# **Завдання 3.** Виведіть кількість підписників по кожній країні. Відсортуйте за спаданням.
#
# > 💡 `value_counts()` вже сортує за спаданням за замовчуванням.

# %%
# Завдання 3:
subs['country'].value_counts()
# Out:
# country
# Україна      256
# Німеччина    101
# Польща        77
# Чехія         68
# Іспанія       62
# Литва         36
# Name: count, dtype: int64

# %% [markdown]
# **Завдання 4.** Знайдіть середній вік підписників.

# %%
# Завдання 4:
avg_age = subs['age'].mean()
avg_age
print(f'Average age: {avg_age:.1f}')
# Out:
# Average age: 43.2

# %% [markdown]
# **Завдання 5.** Знайдіть мінімальну та максимальну тривалість сеансу.

# %%
# Завдання 5:
min_sess = sess['duration_min'].min()
min_sess
print(f'Minimum duration: {min_sess}')

max_sess = sess['duration_min'].max()
max_sess
print(f'Maximum duration: {max_sess}')
# Out:
# Minimum duration: 5
# Maximum duration: 171

# %% [markdown]
# **Завдання 6.** Скільки підписників активні (`is_active == "Так"`)?

# %%
# Завдання 6:
act_subs = subs['is_active'].value_counts()
act_subs
# Out:
# is_active
# Так    447
# Ні     153
# Name: count, dtype: int64

# %% [markdown]
# **Завдання 7.** Виведіть тільки сеанси з жанром `Драма` та оцінкою 5.
#
# > 💡 Дві умови через `&`, кожна в дужках.

# %%
# Завдання 7:
drama = sess[(sess['genre'] == 'Драма') & (sess['rating'] == 5)]
drama
# Out:
#       session_id  subscriber_id       date  genre    device  duration_min  \
# 9          51976           1555 2024-04-11  Драма    Mobile            84
# 68         51372           1447 2024-06-19  Драма    Tablet            93
# 74         53138           1074 2024-01-05  Драма    Laptop            48
# 94         52201           1124 2024-06-17  Драма    Laptop            34
# 117        53459           1454 2024-05-04  Драма    Mobile            77
# ...          ...            ...        ...    ...       ...           ...
# 4852       52566           1345 2024-03-28  Драма    Laptop            43
# 4855       51811           1579 2024-04-04  Драма  Smart TV            99
# 4902       53655           1551 2024-06-30  Драма    Laptop            48
# 4939       50494           1468 2024-01-30  Драма  Smart TV            36
# 4988       53514           1383 2024-01-23  Драма  Smart TV            69
#
#       rating
# 9          5
# 68         5
# 74         5
# 94         5
# 117        5
# ...      ...
# 4852       5
# 4855       5
# 4902       5
# 4939       5
# 4988       5
#
# [227 rows x 7 columns]

# %% [markdown]
# **Завдання 8.** Створіть у таблиці `subs` новий стовпець `annual_fee` = `monthly_fee` × 12.

# %%
# Завдання 8:
subs['annual_fee'] = subs['monthly_fee'] * 12
print(subs[['monthly_fee', 'annual_fee']].head(3))
# Out:
#    monthly_fee  annual_fee
# 0          329        3948
# 1          219        2628
# 2          149        1788

# %% [markdown]
# ## Розділ 1.2. loc та iloc (завдання 9-18)
#
# `iloc` працює за **числовими позиціями** (як індекси у списку):
# - `df.iloc[0]` — перший рядок
# - `df.iloc[0:5]` — рядки 0-4
# - `df.iloc[0, 2]` — рядок 0, стовпець 2
# - `df.iloc[:, 1:3]` — усі рядки, стовпці 1-2
#
# `loc` працює за **мітками** (назвами):
# - `df.loc[0]` — рядок з міткою 0
# - `df.loc[df["age"] > 30, "country"]` — фільтр + конкретний стовпець
# - `df.loc[df["plan"] == "Premium", ["age", "country"]]` — фільтр + кілька стовпців

# %% [markdown]
# **Завдання 9.** Виведіть перший рядок таблиці `subs` за допомогою `iloc`.
#
# > 💡 `subs.iloc[0]`.

# %%
# Завдання 9:
subs.iloc[0]
# Out:
# subscriber_id                   1001
# age                               19
# gender                             Ч
# country                      Україна
# plan                         Premium
# monthly_fee                      329
# join_date        2023-02-27 00:00:00
# is_active                         Ні
# annual_fee                      3948
# Name: 0, dtype: object

# %% [markdown]
# **Завдання 10.** Виведіть рядки з 10 по 15 (включно) таблиці `subs` за допомогою `iloc`.
#
# > 💡 `iloc[10:16]` (правий кінець не включається).

# %%
# Завдання 10:
subs.iloc[10:16]
# Out:
#     subscriber_id  age gender  country      plan  monthly_fee  join_date  \
# 10           1011   16      Ч  Іспанія    Family          449 2023-09-17
# 11           1012   56      Ч  Україна  Standard          219 2024-12-08
# 12           1013   25      Ч  Іспанія  Standard          219 2023-01-01
# 13           1014   17      Ч  Україна  Standard          219 2023-07-21
# 14           1015   55      Ж  Україна  Standard          219 2022-02-14
# 15           1016   20      Ч   Польща   Premium          329 2022-06-09
#
#    is_active  annual_fee
# 10       Так        5388
# 11       Так        2628
# 12       Так        2628
# 13       Так        2628
# 14        Ні        2628
# 15        Ні        3948

# %% [markdown]
# **Завдання 11.** Виведіть значення з 5-го рядка, 3-го стовпця таблиці `subs`.
#
# > 💡 `iloc[5, 3]`. Нумерація з нуля!

# %%
# Завдання 11:
subs.iloc[4, 2]
# Out:
# 'Ж'

# %% [markdown]
# **Завдання 12.** Виведіть перші 3 стовпці таблиці `sess` (усі рядки) за допомогою `iloc`.
#
# > 💡 `iloc[:, :3]`.

# %%
# Завдання 12:
sess.iloc[:, :3]
# Out:
#       session_id  subscriber_id       date
# 0          51573           1166 2024-04-11
# 1          50017           1429 2024-06-25
# 2          50861           1404 2024-07-05
# 3          54446           1520 2024-07-01
# 4          51561           1052 2024-06-13
# ...          ...            ...        ...
# 4995       52398           1356 2024-08-19
# 4996       51013           1208 2024-03-17
# 4997       54579           1174 2024-05-25
# 4998       52743           1431 2024-07-23
# 4999       54629           1237 2024-03-15
#
# [5000 rows x 3 columns]

# %% [markdown]
# **Завдання 13.** Виведіть рядки 100-104, тільки стовпці `age` та `country`. Використайте `iloc`.
#
# > 💡 `iloc[100:105, [1, 3]]` — індекси стовпців: age=1, country=3.

# %%
# Завдання 13:
subs.iloc[100:105, [1, 3]]
# Out:
#      age    country
# 100   63     Польща
# 101   21  Німеччина
# 102   62     Польща
# 103   48    Україна
# 104   54    Україна

# %% [markdown]
# **Завдання 14.** За допомогою `loc` виведіть тільки тих підписників, у яких вік більше 50. Поверніть тільки стовпці `country` та `plan`.
#
# > 💡 `subs.loc[subs["age"] > 50, ["country", "plan"]]`.

# %%
# Завдання 14:
subs.loc[subs['age'] > 50, ['country', 'plan']]
# Out:
#        country      plan
# 2      Україна     Basic
# 11     Україна  Standard
# 14     Україна  Standard
# 16   Німеччина  Standard
# 18      Польща  Standard
# ..         ...       ...
# 593    Іспанія     Basic
# 594    Україна     Basic
# 595    Україна   Premium
# 598      Чехія  Standard
# 599     Польща  Standard
#
# [216 rows x 2 columns]

# %% [markdown]
# **Завдання 15.** За допомогою `loc` виведіть стовпець `monthly_fee` тільки для активних підписників (`is_active == "Так"`).

# %%
# Завдання 15:
subs.loc[subs['is_active'] == 'Так', ['monthly_fee']]
# Out:
#      monthly_fee
# 1            219
# 2            149
# 3            149
# 4            219
# 5            219
# ..           ...
# 594          149
# 595          329
# 596          449
# 597          449
# 599          219
#
# [447 rows x 1 columns]

# %% [markdown]
# **Завдання 16.** Знайдіть середній вік підписників з тарифом `Premium`, використовуючи `loc`.
#
# > 💡 `subs.loc[subs["plan"]=="Premium", "age"].mean()`.

# %%
# Завдання 16:
subs.loc[subs['plan']=='Premium', 'age'].mean()
print(f'Average age with Premium: {subs.loc[subs['plan']=='Premium', 'age'].mean():.1f}')
# Out:
# Average age with Premium: 42.3

# %% [markdown]
# **Завдання 17.** Використовуючи `loc`, ЗМІНІТЬ значення `is_active` на `"Так"` для підписника з `subscriber_id == 1001`.
#
# > 💡 `subs.loc[subs["subscriber_id"]==1001, "is_active"] = "Так"`. Потім перевірте результат.

# %%
# Завдання 17:
print(subs[subs["subscriber_id"] == 1001][["subscriber_id", "is_active"]])

subs.loc[subs["subscriber_id"] == 1001, "is_active"] = "Так"
print("\nAfter changes:")
print(subs[subs["subscriber_id"] == 1001][["subscriber_id", "is_active"]])
# Out:
#    subscriber_id is_active
# 0           1001        Ні
#
# After changes:
#    subscriber_id is_active
# 0           1001       Так

# %% [markdown]
# **Завдання 18.** Виведіть останні 5 рядків таблиці `subs` за допомогою `iloc` (без `tail`).
#
# > 💡 Від'ємні індекси: `iloc[-5:]`.

# %%
# Завдання 18:
subs.iloc[-5:]
# Out:
#      subscriber_id  age gender    country      plan  monthly_fee  join_date  \
# 595           1596   53      Ж    Україна   Premium          329 2022-04-15
# 596           1597   30      Ч    Україна    Family          449 2024-03-26
# 597           1598   38      Ч  Німеччина    Family          449 2024-06-12
# 598           1599   64      Ж      Чехія  Standard          219 2024-05-03
# 599           1600   68      Ч     Польща  Standard          219 2022-07-28
#
#     is_active  annual_fee
# 595       Так        3948
# 596       Так        5388
# 597       Так        5388
# 598        Ні        2628
# 599       Так        2628

# %% [markdown]
# ## Розділ 1.3. Складніший groupby (завдання 19-28)
#
# Нові можливості:
# - `.agg(["sum", "mean", "count"])` — кілька агрегатів одразу
# - `.agg({"col1": "mean", "col2": "sum"})` — різні агрегати на різні стовпці
# - `.transform("mean")` — повертає те саме число для кожного рядка групи (зручно для нових стовпців)
# - `groupby(["col1", "col2"])` — групування за кількома стовпцями
# - `.size()` — кількість рядків у кожній групі

# %% [markdown]
# **Завдання 19.** Для кожної країни виведіть кількість підписників та середній вік за один виклик `agg`.
#
# > 💡 `subs.groupby("country").agg({"subscriber_id": "count", "age": "mean"})`.

# %%
# Завдання 19:
subs.groupby('country').agg({'subscriber_id': 'count', 'age': 'mean'})
# Out:
#            subscriber_id        age
# country
# Іспанія               62  43.080645
# Литва                 36  40.416667
# Німеччина            101  45.099010
# Польща                77  42.961039
# Україна              256  43.566406
# Чехія                 68  40.529412

# %% [markdown]
# **Завдання 20.** Для кожного тарифу (`plan`) виведіть мінімальний, середній і максимальний вік підписників.
#
# > 💡 `agg(["min", "mean", "max"])` на стовпці `age`.

# %%
# Завдання 20:
subs.groupby('plan').agg({'age': ['min', 'mean', 'max']})
# Out:
#          age
#          min       mean max
# plan
# Basic     16  44.521739  70
# Family    16  41.934783  70
# Premium   16  42.290780  70
# Standard  16  43.375546  70

# %% [markdown]
# **Завдання 21.** Для кожного жанру в таблиці `sess` порахуйте кількість сеансів та середню тривалість.
#
# > 💡 `sess.groupby("genre").agg({"session_id": "count", "duration_min": "mean"})`.

# %%
# Завдання 21:
sess.groupby('genre').agg({'session_id': 'count', 'duration_min': 'mean'})
# Out:
#                 session_id  duration_min
# genre
# Анімація               653     53.430322
# Бойовик                661     52.856278
# Документальний         573     52.657941
# Драма                  578     52.861592
# Жахи                   631     52.240887
# Комедія                629     54.125596
# Романтика              644     54.711180
# Серіал                 631     53.954041

# %% [markdown]
# **Завдання 22.** Для кожного пристрою порахуйте середню оцінку (`rating`) та середню тривалість (`duration_min`).

# %%
# Завдання 22:
sess.groupby('device').agg({'rating': 'mean', 'duration_min': 'mean'})
# Out:
#             rating  duration_min
# device
# Laptop    3.983550     52.854010
# Mobile    3.991426     52.825409
# Smart TV  4.052541     53.613935
# Tablet    4.007890     55.376726

# %% [markdown]
# **Завдання 23.** Згрупуйте сеанси за двома стовпцями: `genre` та `device`. Порахуйте середню оцінку.
#
# > 💡 `groupby(["genre", "device"])["rating"].mean()`.

# %%
# Завдання 23:
sess.groupby(['genre', 'device'])['rating'].mean()
# Out:
# genre           device
# Анімація        Laptop      3.913514
#                 Mobile      4.066265
#                 Smart TV    4.008811
#                 Tablet      3.880000
# Бойовик         Laptop      4.077720
#                 Mobile      3.805714
#                 Smart TV    3.905830
#                 Tablet      4.071429
# Документальний  Laptop      4.028571
#                 Mobile      4.000000
#                 Smart TV    4.116822
#                 Tablet      3.979167
# Драма           Laptop      3.967532
#                 Mobile      4.107595
#                 Smart TV    4.106280
#                 Tablet      4.203390
# Жахи            Laptop      3.955556
#                 Mobile      3.987654
#                 Smart TV    4.080952
#                 Tablet      4.139241
# Комедія         Laptop      3.989130
#                 Mobile      4.019481
#                 Smart TV    4.021459
#                 Tablet      3.965517
# Романтика       Laptop      3.995074
#                 Mobile      3.915663
#                 Smart TV    4.092166
#                 Tablet      4.086207
# Серіал          Laptop      3.935135
#                 Mobile      4.048193
#                 Smart TV    4.100000
#                 Tablet      3.716667
# Name: rating, dtype: float64

# %% [markdown]
# **Завдання 24.** Скільки сеансів припадає на кожну пару (`genre`, `device`)? Використайте `.size()`.

# %%
# Завдання 24:
sess.groupby(['genre', 'device'])['session_id'].size()
# Out:
# genre           device
# Анімація        Laptop      185
#                 Mobile      166
#                 Smart TV    227
#                 Tablet       75
# Бойовик         Laptop      193
#                 Mobile      175
#                 Smart TV    223
#                 Tablet       70
# Документальний  Laptop      175
#                 Mobile      136
#                 Smart TV    214
#                 Tablet       48
# Драма           Laptop      154
#                 Mobile      158
#                 Smart TV    207
#                 Tablet       59
# Жахи            Laptop      180
#                 Mobile      162
#                 Smart TV    210
#                 Tablet       79
# Комедія         Laptop      184
#                 Mobile      154
#                 Smart TV    233
#                 Tablet       58
# Романтика       Laptop      203
#                 Mobile      166
#                 Smart TV    217
#                 Tablet       58
# Серіал          Laptop      185
#                 Mobile      166
#                 Smart TV    220
#                 Tablet       60
# Name: session_id, dtype: int64

# %% [markdown]
# **Завдання 25.** Додайте до таблиці `sess` новий стовпець `avg_rating_genre` — середня оцінка по жанру для цього сеансу. Використайте `.transform("mean")`.
#
# > 💡 `sess["avg_rating_genre"] = sess.groupby("genre")["rating"].transform("mean")`.

# %%
# Завдання 25:
sess['avg_rating_genre'] = sess.groupby('genre')['rating'].transform('mean').round(2)
print(sess[['session_id', 'genre', 'rating', 'avg_rating_genre']].head())
# Out:
#    session_id      genre  rating  avg_rating_genre
# 0       51573   Анімація       1              3.98
# 1       50017  Романтика       5              4.02
# 2       50861    Бойовик       5              3.95
# 3       54446     Серіал       3              4.00
# 4       51561    Бойовик       5              3.95

# %% [markdown]
# **Завдання 26.** Додайте до таблиці `subs` стовпець `avg_age_country` — середній вік підписників у країні цього підписника.

# %%
# Завдання 26:
subs['avg_age_country'] = subs.groupby('country')['age'].transform('mean').round(1)

print(subs[['age', 'country', 'avg_age_country']].head())
# Out:
#    age  country  avg_age_country
# 0   19  Україна             43.6
# 1   40   Польща             43.0
# 2   60  Україна             43.6
# 3   36    Чехія             40.5
# 4   34  Іспанія             43.1

# %% [markdown]
# **Завдання 27.** Знайдіть країну з найбільшим середнім віком підписників.
#
# > 💡 `groupby + mean + idxmax()` АБО `sort_values(ascending=False).head(1)`.

# %%
# Завдання 27:
state_avg_age = subs.groupby('country')['age'].mean()
state_avg_age

state_avg_age = state_avg_age.sort_values(ascending=False).head(1)
state_avg_age
# Out:
# country
# Німеччина    45.09901
# Name: age, dtype: float64

# %% [markdown]
# **Завдання 28.** Для кожної країни порахуйте, скільки активних і скільки неактивних підписників. Використайте `groupby` за двома стовпцями + `size()`.
#
# > 💡 `subs.groupby(["country", "is_active"]).size()`.

# %%
# Завдання 28:
subs.groupby(["country", "is_active"]).size()
# Out:
# country    is_active
# Іспанія    Ні            16
#            Так           46
# Литва      Ні             7
#            Так           29
# Німеччина  Ні            29
#            Так           72
# Польща     Ні            21
#            Так           56
# Україна    Ні            66
#            Так          190
# Чехія      Ні            13
#            Так           55
# dtype: int64

# %% [markdown]
# ## Розділ 1.4. pivot_table — зведені таблиці (завдання 29-36)
#
# `pivot_table` створює таблицю, де:
# - `index` — що ставимо у рядки
# - `columns` — що ставимо у стовпці
# - `values` — що рахуємо
# - `aggfunc` — який агрегат (за замовч. `"mean"`)
#
# Приклад:
# ```python
# pd.pivot_table(df, index="country", columns="plan", values="age", aggfunc="mean")
# ```

# %% [markdown]
# **Завдання 29.** Створіть зведену таблицю: рядки — `country`, стовпці — `plan`, значення — кількість підписників.
#
# > 💡 `aggfunc="count"`, як `values` можна взяти `subscriber_id`.

# %%
# Завдання 29:
pd.pivot_table(subs, index='country', columns='plan', values='subscriber_id', aggfunc='count')
# Out:
# plan       Basic  Family  Premium  Standard
# country
# Іспанія       18       9       13        22
# Литва          5       7       10        14
# Німеччина     24      17       19        41
# Польща        10       9       23        35
# Україна       68      34       60        94
# Чехія         13      16       16        23

# %% [markdown]
# **Завдання 30.** Зведена таблиця: рядки — `country`, стовпці — `plan`, значення — середній вік.
#
# > 💡 `aggfunc="mean"` (за замовчуванням).

# %%
subs.head()
# Out:
#    subscriber_id  age gender  country      plan  monthly_fee  join_date  \
# 0           1001   19      Ч  Україна   Premium          329 2023-02-27
# 1           1002   40      Ж   Польща  Standard          219 2022-03-05
# 2           1003   60      Ч  Україна     Basic          149 2023-02-20
# 3           1004   36      Ч    Чехія     Basic          149 2022-02-22
# 4           1005   34      Ж  Іспанія  Standard          219 2023-08-27
#
#   is_active  annual_fee  avg_age_country
# 0       Так        3948             43.6
# 1       Так        2628             43.0
# 2       Так        1788             43.6
# 3       Так        1788             40.5
# 4       Так        2628             43.1

# %%
# Завдання 30:
pd.pivot_table(subs, index='country', columns='plan', values='avg_age_country', aggfunc='mean')
# Out:
# plan       Basic  Family  Premium  Standard
# country
# Іспанія     43.1    43.1     43.1      43.1
# Литва       40.4    40.4     40.4      40.4
# Німеччина   45.1    45.1     45.1      45.1
# Польща      43.0    43.0     43.0      43.0
# Україна     43.6    43.6     43.6      43.6
# Чехія       40.5    40.5     40.5      40.5

# %% [markdown]
# **Завдання 31.** Зведена таблиця по сеансах: рядки — `genre`, стовпці — `device`, значення — середня оцінка.

# %%
sess.head(1)
# Out:
#    session_id  subscriber_id       date     genre  device  duration_min  \
# 0       51573           1166 2024-04-11  Анімація  Mobile            72
#
#    rating  avg_rating_genre
# 0       1              3.98

# %%
# Завдання 31:
pd.pivot_table(sess, index='genre', columns='device', values='avg_rating_genre', aggfunc='mean')
# Out:
# device          Laptop  Mobile  Smart TV  Tablet
# genre
# Анімація          3.98    3.98      3.98    3.98
# Бойовик           3.95    3.95      3.95    3.95
# Документальний    4.05    4.05      4.05    4.05
# Драма             4.08    4.08      4.08    4.08
# Жахи              4.03    4.03      4.03    4.03
# Комедія           4.01    4.01      4.01    4.01
# Романтика         4.02    4.02      4.02    4.02
# Серіал            4.00    4.00      4.00    4.00

# %% [markdown]
# **Завдання 32.** Зведена таблиця: рядки — `genre`, стовпці — `device`, значення — сумарна тривалість сеансів.
#
# > 💡 `aggfunc="sum"`.

# %%
# Завдання 32:
pd.pivot_table(sess, index='genre', columns='device', values='duration_min', aggfunc='sum')
# Out:
# device          Laptop  Mobile  Smart TV  Tablet
# genre
# Анімація          9358    8700     12457    4375
# Бойовик          10023    9625     11471    3819
# Документальний    9116    6731     11690    2636
# Драма             8050    8391     10806    3307
# Жахи              9479    8513     11095    3877
# Комедія          10208    8427     12034    3376
# Романтика        10659    8610     12685    3280
# Серіал           10221    8778     11640    3406

# %% [markdown]
# **Завдання 33.** Зведена таблиця: рядки — `country`, стовпці — `gender`, значення — кількість підписників.

# %%
# Завдання 33:
pd.pivot_table(subs, index='country', columns='gender', values='subscriber_id', aggfunc='count', fill_value=0)
# Out:
# gender       Ж    Ч
# country
# Іспанія     32   30
# Литва       22   14
# Німеччина   51   50
# Польща      40   37
# Україна    132  124
# Чехія       36   32

# %% [markdown]
# **Завдання 34.** Зведена таблиця: рядки — `plan`, стовпці — `is_active`, значення — кількість підписників.

# %%
# Завдання 34:
pd.pivot_table(subs, index='plan', columns='is_active', values='subscriber_id', aggfunc='count')
# Out:
# is_active  Ні  Так
# plan
# Basic      35  103
# Family     26   66
# Premium    41  100
# Standard   50  179

# %% [markdown]
# **Завдання 35.** Створіть зведену таблицю по сеансах: `genre` у рядках, `device` у стовпцях, кількість сеансів. Заповніть пропуски нулями.
#
# > 💡 Параметр `fill_value=0`.

# %%
# Завдання 35:
pd.pivot_table(sess, index='genre', columns='device', values= 'session_id', aggfunc='count', fill_value=0)
# Out:
# device          Laptop  Mobile  Smart TV  Tablet
# genre
# Анімація           185     166       227      75
# Бойовик            193     175       223      70
# Документальний     175     136       214      48
# Драма              154     158       207      59
# Жахи               180     162       210      79
# Комедія            184     154       233      58
# Романтика          203     166       217      58
# Серіал             185     166       220      60

# %% [markdown]
# **Завдання 36.** Зведена таблиця: рядки — `country`, значення — кількість підписників та середній `monthly_fee` одночасно.
#
# > 💡 `values=["subscriber_id", "monthly_fee"]` плюс `aggfunc={"subscriber_id":"count", "monthly_fee":"mean"}`.

# %%
# Завдання 36:
pd.pivot_table(subs, index='country', values=['subscriber_id', 'monthly_fee'], aggfunc={'subscriber_id': 'count', 'monthly_fee': 'mean'} )
# Out:
#            monthly_fee  subscriber_id
# country
# Іспанія     255.129032             62
# Литва       284.555556             36
# Німеччина   261.772277            101
# Польща      269.649351             77
# Україна     256.734375            256
# Чехія       285.617647             68

# %% [markdown]
# ## Розділ 1.5. Робота з датами + обчислення (завдання 37-44)
#
# Нагадування: дати вже перетворено на datetime у комірці підготовки.
# - `.dt.year`, `.dt.month`, `.dt.day` — частини дати
# - `.dt.day_name()` — назва дня тижня
# - Можна віднімати дати: `df["date1"] - df["date2"]` (отримуємо тривалість)

# %% [markdown]
# **Завдання 37.** Додайте до таблиці `sess` стовпець `month` — місяць сеансу.

# %%
# Завдання 37:
sess['month'] = sess['date'].dt.month
sess.head(1)
# Out:
#    session_id  subscriber_id       date     genre  device  duration_min  \
# 0       51573           1166 2024-04-11  Анімація  Mobile            72
#
#    rating  avg_rating_genre  month
# 0       1              3.98      4

# %% [markdown]
# **Завдання 38.** Додайте до таблиці `sess` стовпець `weekday` — назву дня тижня.
#
# > 💡 `.dt.day_name()`.

# %%
# Завдання 38:
sess['weekday'] = sess['date'].dt.day_name()
sess.head(10)
# Out:
#    session_id  subscriber_id       date           genre    device  \
# 0       51573           1166 2024-04-11        Анімація    Mobile
# 1       50017           1429 2024-06-25       Романтика    Mobile
# 2       50861           1404 2024-07-05         Бойовик  Smart TV
# 3       54446           1520 2024-07-01          Серіал    Laptop
# 4       51561           1052 2024-06-13         Бойовик    Laptop
# 5       51938           1078 2024-08-27  Документальний    Mobile
# 6       52050           1343 2024-02-26         Бойовик    Tablet
# 7       54963           1444 2024-08-04          Серіал  Smart TV
# 8       50908           1521 2024-04-02           Драма  Smart TV
# 9       51976           1555 2024-04-11           Драма    Mobile
#
#    duration_min  rating  avg_rating_genre  month   weekday
# 0            72       1              3.98      4  Thursday
# 1            53       5              4.02      6   Tuesday
# 2            49       5              3.95      7    Friday
# 3            66       3              4.00      7    Monday
# 4            81       5              3.95      6  Thursday
# 5            60       4              4.05      8   Tuesday
# 6            86       3              3.95      2    Monday
# 7            56       4              4.00      8    Sunday
# 8            68       4              4.08      4   Tuesday
# 9            84       5              4.08      4  Thursday

# %% [markdown]
# **Завдання 39.** Скільки сеансів припадає на кожен місяць? Відсортуйте за номером місяця.
#
# > 💡 `groupby("month")` + `size()` або `count`.

# %%
# Завдання 39:
sess_per_month = sess.groupby('month')['session_id'].size()
sess_per_month
# Out:
# month
# 1    667
# 2    627
# 3    627
# 4    601
# 5    635
# 6    599
# 7    664
# 8    580
# Name: session_id, dtype: int64

# %% [markdown]
# **Завдання 40.** У який день тижня користувачі переглядають найбільше? Згрупуйте за `weekday`, порахуйте кількість сеансів.

# %%
# Завдання 40:
weekday_count = sess.groupby('weekday')['session_id'].count()
weekday_count = weekday_count.sort_values(ascending=False)
weekday_count
# Out:
# weekday
# Monday       736
# Wednesday    726
# Saturday     719
# Thursday     713
# Tuesday      708
# Friday       706
# Sunday       692
# Name: session_id, dtype: int64

# %%
weekday_count = sess['weekday'].value_counts()
weekday_count
# Out:
# weekday
# Monday       736
# Wednesday    726
# Saturday     719
# Thursday     713
# Tuesday      708
# Friday       706
# Sunday       692
# Name: count, dtype: int64

# %% [markdown]
# **Завдання 41.** Скільки сеансів відбулось у червні 2024? Відфільтруйте, потім порахуйте.
#
# > 💡 `sess[sess["date"].dt.month == 6]` (бо всі дані за 2024 рік).

# %%
# Завдання 41:
june_data = sess[sess["date"].dt.month == 6]
count_june = len(june_data)
print(f'In June there were: {count_june} sessions')
# Out:
# In June there were: 599 sessions

# %%
print(sess[sess["date"].dt.month == 6].shape[0])
# Out:
# 599

# %% [markdown]
# **Завдання 42.** Додайте до таблиці `subs` стовпець `years_with_us` — скільки років підписник з нами (різниця між 2024-12-31 та `join_date` у роках).
#
# > 💡 `(pd.Timestamp("2024-12-31") - subs["join_date"]).dt.days / 365` — округліть як хочете.

# %%
# Завдання 42:
subs['years_with_us'] = ((pd.Timestamp("2024-12-31") - subs["join_date"]).dt.days / 365).round(1)
print(subs[['join_date', 'years_with_us']].head())
# Out:
#    join_date  years_with_us
# 0 2023-02-27            1.8
# 1 2022-03-05            2.8
# 2 2023-02-20            1.9
# 3 2022-02-22            2.9
# 4 2023-08-27            1.3

# %% [markdown]
# **Завдання 43.** Скільки нових підписників прийшло у кожному році (за `join_date`)? Згрупуйте за роком.
#
# > 💡 `subs["join_date"].dt.year` + `value_counts`.

# %%
# Завдання 43:
yearly_subs = subs['join_date'].dt.year.value_counts()

print(yearly_subs)
# Out:
# join_date
# 2022    209
# 2023    208
# 2024    183
# Name: count, dtype: int64

# %% [markdown]
# **Завдання 44.** Знайдіть місяць 2024 року, коли було найбільше переглядів. Виведіть номер місяця та кількість сеансів.

# %%
# Завдання 44:
top_month = sess['month'].value_counts().head(1)
top_month
# Out:
# month
# 1    667
# Name: count, dtype: int64

# %% [markdown]
# ## Розділ 1.6. Комбіновані завдання (завдання 45-50)
#
# Найскладніші — поєднують різні концепції.

# %% [markdown]
# **Завдання 45.** Знайдіть топ-5 підписників за СУМАРНОЮ тривалістю переглядів. Виведіть `subscriber_id` та сумарну тривалість.
#
# > 💡 Згрупуйте `sess` за `subscriber_id`, порахуйте суму `duration_min`, відсортуйте, візьміть head(5).

# %%
# Завдання 45:
sess.groupby('subscriber_id')['duration_min'].sum().sort_values(ascending=False).head()
# Out:
# subscriber_id
# 1020    1184
# 1549    1165
# 1479    1138
# 1535    1081
# 1252    1019
# Name: duration_min, dtype: int64

# %% [markdown]
# **Завдання 46.** Для кожного жанру знайдіть відсоток сеансів від загальної кількості сеансів.
#
# > 💡 `value_counts(normalize=True) * 100` АБО `groupby + size`, поділене на `len(sess)`, * 100.

# %%
# Завдання 46:
genre_percentages = (sess['genre'].value_counts(normalize=True) * 100).round(1)

print(genre_percentages)
# Out:
# genre
# Бойовик           13.2
# Анімація          13.1
# Романтика         12.9
# Серіал            12.6
# Жахи              12.6
# Комедія           12.6
# Драма             11.6
# Документальний    11.5
# Name: proportion, dtype: float64

# %% [markdown]
# **Завдання 47.** Знайдіть жанр, який має найвищу середню оцінку (`rating`).
#
# > 💡 `groupby + mean + idxmax`.

# %%
# Завдання 47:
best_genre = sess.groupby('genre')['rating'].mean().idxmax()
best_genre
# Out:
# 'Драма'

# %% [markdown]
# **Завдання 48.** Скільки сеансів у кожній країні? Підказка: треба об'єднати дві таблиці.
#
# > 💡 Використайте `merge`: `sess.merge(subs[["subscriber_id", "country"]], on="subscriber_id")`, потім `groupby("country").size()`.

# %%
# Завдання 48:
merged = sess.merge(subs[['subscriber_id', 'country']], on='subscriber_id')
sess_by_country = merged.groupby('country').size()
sess_by_country
# Out:
# country
# Іспанія       520
# Литва         321
# Німеччина     857
# Польща        626
# Україна      2114
# Чехія         562
# dtype: int64

# %% [markdown]
# **Завдання 49.** Який тариф (`plan`) дає найбільшу СЕРЕДНЮ тривалість сеансу? Об'єднайте таблиці, потім згрупуйте.
#
# > 💡 `sess.merge(subs[["subscriber_id","plan"]], on="subscriber_id")` потім `groupby("plan")["duration_min"].mean()`.

# %%
# Завдання 49:
merged = sess.merge(subs[['subscriber_id', 'plan']], on='subscriber_id')
sess_by_plan = merged.groupby('plan')['duration_min'].mean().idxmax()
sess_by_plan
# Out:
# 'Family'

# %% [markdown]
# **Завдання 50.** Для кожної країни знайдіть популярний жанр (з найбільшою кількістю сеансів).
#
# > 💡 Об'єднайте таблиці, згрупуйте за `["country", "genre"]`, порахуйте `size`, потім для кожної країни знайдіть жанр з максимумом. Підказка: можна `.groupby("country").idxmax()`.

# %%
sess.head()
# Out:
#    session_id  subscriber_id       date      genre    device  duration_min  \
# 0       51573           1166 2024-04-11   Анімація    Mobile            72
# 1       50017           1429 2024-06-25  Романтика    Mobile            53
# 2       50861           1404 2024-07-05    Бойовик  Smart TV            49
# 3       54446           1520 2024-07-01     Серіал    Laptop            66
# 4       51561           1052 2024-06-13    Бойовик    Laptop            81
#
#    rating  avg_rating_genre  month   weekday
# 0       1              3.98      4  Thursday
# 1       5              4.02      6   Tuesday
# 2       5              3.95      7    Friday
# 3       3              4.00      7    Monday
# 4       5              3.95      6  Thursday

# %%
# Завдання 50:
merged = sess.merge(subs[['subscriber_id', 'country']], on='subscriber_id')
genre_by_country = merged.groupby(['country', 'genre']).size().groupby('country').idxmax()
genre_by_country
# Out:
# country
# Іспанія      (Іспанія, Романтика)
# Литва               (Литва, Жахи)
# Німеччина    (Німеччина, Комедія)
# Польща        (Польща, Романтика)
# Україна        (Україна, Бойовик)
# Чехія             (Чехія, Серіал)
# dtype: object

# %% [markdown]
# ---
#
# # Частина 2. Візуалізація (30 завдань)
#
# Розділи:
# 1. Швидкі графіки через pandas `.plot()` (51-58)
# 2. Основні типи matplotlib (59-66)
# 3. Налаштування графіків — заголовки, осі, кольори (67-74)
# 4. Легенди, кілька серій, subplots (75-80)
#
# > 💡 **Загальне правило:** після кожного `plt....` коду додавайте `plt.show()` — це показує графік.

# %% [markdown]
# ## Розділ 2.1. Швидкі графіки через pandas (завдання 51-58)
#
# pandas вміє будувати швидкі графіки прямо з даних — метод `.plot()`. Це найшвидший спосіб подивитись на дані.
#
# Параметри:
# - `kind="bar"` — стовпчаста діаграма
# - `kind="barh"` — горизонтальна стовпчаста
# - `kind="line"` — лінійна (за замовчуванням)
# - `kind="hist"` — гістограма
# - `kind="pie"` — кругова
# - `kind="scatter"` — точкова (треба вказати `x` і `y`)
# - `title="..."` — заголовок

# %% [markdown]
# **Завдання 51.** Побудуйте стовпчасту діаграму кількості підписників по країнах.
#
# > 💡 `subs["country"].value_counts().plot(kind="bar")` + `plt.show()`.

# %%
# Завдання 51:
country_count = subs['country'].value_counts()
country_count.plot(kind='bar')
plt.show()

# %% [markdown]
# **Завдання 52.** Побудуйте кругову діаграму (`pie`) розподілу підписників за тарифами.
#
# > 💡 `value_counts().plot(kind="pie")`.

# %%
# Завдання 52:
sub_plan = subs['plan'].value_counts()
sub_plan.plot(kind='pie')
plt.show()

# %% [markdown]
# **Завдання 53.** Побудуйте гістограму розподілу віку підписників.
#
# > 💡 `subs["age"].plot(kind="hist")`.

# %%
# Завдання 53:
sub_age = subs['age']
sub_age.plot(kind='hist', edgecolor='black')
plt.show()

# %%
sess['duration_min'].plot(
    kind='hist',
    bins=20,
    color='skyblue',      # приємний небесний колір
    edgecolor='white',    # білі межі замість чорних виглядають сучасніше
    alpha=0.8,            # легка прозорість
    rwidth=0.95           # робить стовпчики окремими, а не суцільною стіною
)
plt.show()

# %% [markdown]
# I was trying with chatGPT to improve the look... but still I don't like it... :(

# %% [markdown]
# **Завдання 54.** Побудуйте гістограму тривалості сеансів з 20 інтервалами (bins).
#
# > 💡 Параметр `bins=20`.

# %%
# Завдання 54:
sess['duration_min'].plot(kind='hist', bins=20, edgecolor='black')
plt.show()

# %%
sess['duration_min'].plot(kind='kde', color='purple', linewidth=2)
plt.show()

sess['duration_min'].plot(kind='hist', bins=20, color='teal', alpha=0.7)
plt.show()

# %% [markdown]
# **Завдання 55.** Побудуйте лінійну діаграму кількості сеансів по місяцях. Спочатку згрупуйте за місяцем, потім `.plot()`.
#
# > 💡 `sess.groupby("month").size().plot()`.

# %%
# Завдання 55:
monthly_sessions = sess.groupby("month").size()
monthly_sessions.plot(color='#1f77b4', linewidth=2.5, marker='o')
plt.show()

# %% [markdown]
# **Завдання 56.** Побудуйте горизонтальну стовпчасту діаграму кількості сеансів по жанрах.
#
# > 💡 `kind="barh"`.

# %%
# Завдання 56:
genre_count = sess.groupby('genre').size()
genre_count.plot(kind='barh', color='teal', edgecolor='black', alpha=0.8)
plt.show()

# %% [markdown]
# **Завдання 57.** Побудуйте стовпчасту діаграму середньої оцінки (`rating`) по жанрах.
#
# > 💡 `groupby("genre")["rating"].mean().plot(kind="bar")`.

# %%
# Завдання 57:
genre_rating = sess.groupby("genre")["rating"].mean().sort_values(ascending=False)
genre_rating.plot(kind="bar", color="salmon", edgecolor="black", alpha=0.8)
plt.show()

# %% [markdown]
# The previous graph wa unreadable for me, that's why I asked chat... here is the solution, but also not so clear imho...

# %%
genre_rating = sess.groupby("genre")["rating"].mean().sort_values(ascending=False)
genre_rating.plot(kind="bar", color="salmon", edgecolor="black", alpha=0.8)
plt.ylim(3, 5)
plt.xticks(rotation=0)
plt.title("Які жанри оцінюють найвище?")
plt.ylabel("Середня оцінка (від 3 до 5)")
plt.xlabel("Жанр кіно")
plt.grid(axis='y', linestyle='--', alpha=0.3)

# %% [markdown]
# **Завдання 58.** Побудуйте scatter plot (точкову): по осі X — `duration_min`, по осі Y — `rating` (з таблиці `sess`).
#
# > 💡 `sess.plot(kind="scatter", x="duration_min", y="rating")`.

# %%
# Завдання 58:
sess.plot(kind="scatter", x="duration_min", y="rating", color="darkblue", alpha=0.5, figsize=(9, 5))

plt.title("Зв'язок між тривалістю сеансу та оцінкою")
plt.xlabel("Тривалість (хв)")
plt.ylabel("Оцінка (рейтинг)")
plt.grid(True, linestyle='--', alpha=0.3)

plt.show()

# %% [markdown]
# ## Розділ 2.2. Основи matplotlib (завдання 59-66)
#
# matplotlib дає більше контролю. Базовий синтаксис:
#
# ```python
# plt.figure(figsize=(8, 5))   # розмір графіка
# plt.bar(категорії, значення) # bar / line / scatter / hist
# plt.title("Заголовок")
# plt.xlabel("Назва X")
# plt.ylabel("Назва Y")
# plt.show()
# ```
#
# Функції: `plt.bar()`, `plt.barh()`, `plt.plot()`, `plt.hist()`, `plt.scatter()`, `plt.pie()`.

# %% [markdown]
# **Завдання 59.** Створіть стовпчасту діаграму через `plt.bar()`. По осі X — країни, по осі Y — кількість підписників.
#
# > 💡 Спочатку отримайте дані: `counts = subs["country"].value_counts()`. Потім: `plt.bar(counts.index, counts.values)`.

# %%
# Завдання 59:
counts = subs["country"].value_counts()
plt.figure(figsize=(8, 5))
plt.bar(counts.index, counts.values, color="cornflowerblue", edgecolor="black")
plt.title("Division by country")
plt.xlabel("Country")
plt.ylabel("Amount of subscribers")

plt.show()

# %% [markdown]
# **Завдання 60.** Створіть лінійну діаграму через `plt.plot()`: динаміка кількості сеансів по місяцях.
#
# > 💡 `monthly = sess.groupby("month").size()` + `plt.plot(monthly.index, monthly.values)`.

# %%
# Завдання 60:
monthly = sess.groupby("month").size()
plt.figure(figsize=(8, 5))
plt.plot(monthly.index, monthly.values, color="crimson", linewidth=2.5, marker="o")
plt.title("Monthly Dynamic")
plt.show()

# %% [markdown]
# **Завдання 61.** Створіть гістограму віку підписників через `plt.hist()` з 15 інтервалами.
#
# > 💡 `plt.hist(subs["age"], bins=15)`.

# %%
# Завдання 61:
plt.figure(figsize=(8,5))
plt.hist(subs["age"], bins=15, color="darkblack" if False else "mediumpurple", edgecolor="white", alpha=0.9)

plt.title("Division by age")
plt.xlabel("Age (years)")
plt.ylabel("Amount of subscribers")
# Out:
# Text(0, 0.5, 'Amount of subscribers')

# %% [markdown]
# **Завдання 62.** Створіть точкову діаграму через `plt.scatter()`: вік підписників по X, місячна плата по Y.
#
# > 💡 `plt.scatter(subs["age"], subs["monthly_fee"])`.

# %%
# Завдання 62:
plt.figure(figsize=(8,5))
plt.scatter(subs["age"], subs["monthly_fee"], color="#2ecc71", alpha=0.6, edgecolor="none")
plt.title("Dependence of the monthly fee on the subscriber's age")
plt.xlabel('Subscribers age')
plt.ylabel('Monthly fee ($)')
plt.grid(True, linestyle="--", alpha=0.4)
plt.show()

# %% [markdown]
# **Завдання 63.** Створіть кругову діаграму через `plt.pie()`: розподіл сеансів за пристроями.
#
# > 💡 `counts = sess["device"].value_counts()` + `plt.pie(counts.values, labels=counts.index)`.

# %%
# Завдання 63:
counts = sess["device"].value_counts()
plt.figure(figsize=(6,6))

plt.pie(
    counts.values,
    labels=counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=['#ff9999','#66b3ff','#99ff99']
)

plt.title('Session distribution by device')
plt.show()

# %% [markdown]
# **Завдання 64.** Побудуйте графік з розміром 10x6 дюймів через `plt.figure(figsize=...)`. Можна побудувати будь-який — наприклад, кількість сеансів по жанрах.

# %%
# Завдання 64:
genre_counts = sess["genre"].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(genre_counts.index, genre_counts.values, color="dodgerblue", edgecolor="black", alpha=0.8)
plt.title('Total sessions by content genre')
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Number of session', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.4)

plt.show()

# %% [markdown]
# **Завдання 65.** Побудуйте горизонтальну стовпчасту діаграму через `plt.barh()`: кількість сеансів по жанрах.

# %%
# Завдання 65:
genre_counts = sess["genre"].value_counts().sort_values(ascending=True)

plt.figure(figsize=(9, 5))
plt.barh(genre_counts.index, genre_counts.values, color="darkturquoise", edgecolor="black", alpha=0.8)

plt.title('Genre rating')
plt.xlabel('Session numbers')
plt.ylabel('Content genre')
plt.grid(axis='x', linestyle='--', alpha=0.4)

plt.show()

# %% [markdown]
# **Завдання 66.** Побудуйте дві гістограми на одній фігурі (виклик `plt.hist` двічі підряд перед `plt.show()`): вік активних підписників та вік неактивних. Використайте параметр `alpha=0.5` для прозорості.
#
# > 💡 `plt.hist(...активні..., alpha=0.5)` потім `plt.hist(...неактивні..., alpha=0.5)` потім `plt.show()`.

# %%
# Завдання 66:
active_age = subs[subs["is_active"] == "Так"]["age"]
inactive_age = subs[subs["is_active"] == "Ні"]["age"]

plt.figure(figsize=(10, 6))
plt.hist(active_age, bins=15, alpha=0.5, color="blue", edgecolor="darkblue", label="Active")
plt.hist(inactive_age, bins=15, alpha=0.5, color="red", edgecolor="darkred", label="Inactive")

plt.title("Age comparison of active and inactive subscribers", fontsize=14)
plt.xlabel("Age (years)", fontsize=12)
plt.ylabel("Number of subscribers", fontsize=12)

plt.legend()
plt.grid(True, linestyle="--", alpha=0.3)

plt.show()

# %% [markdown]
# ## Розділ 2.3. Налаштування графіків (завдання 67-74)
#
# Тепер додаємо красу і інформативність:
# - `plt.title("...")` — заголовок
# - `plt.xlabel("...")`, `plt.ylabel("...")` — підписи осей
# - `color="..."` — колір (`"red"`, `"#02C39A"`, `"teal"` тощо)
# - `plt.xticks(rotation=45)` — повернути підписи по X
# - `plt.grid(True)` — додати сітку
# - `plt.figure(figsize=(w, h))` — розмір

# %% [markdown]
# **Завдання 67.** Побудуйте стовпчасту діаграму кількості підписників по країнах. Додайте заголовок "Кількість підписників по країнах", підпис осі X "Країна" та осі Y "Кількість".

# %%
# Завдання 67:
counts = subs["country"].value_counts()
plt.figure(figsize=(9, 5))
plt.bar(counts.index, counts.values, color="royalblue", edgecolor="black", alpha=0.8)
plt.title("Amount of subscribers by country", fontsize=14)
plt.xlabel("Country", fontsize=12)
plt.ylabel("Amount", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.show()

# %% [markdown]
# **Завдання 68.** Побудуйте графік середньої тривалості сеансу по жанрах. Усі стовпці зробіть КОЛЬОРОМ `teal`.
#
# > 💡 Параметр `color="teal"` всередині `plt.bar()` або `.plot(kind="bar")`.

# %%
# Завдання 68:
genre_duration = sess.groupby("genre")["duration_min"].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 5))
plt.bar(genre_duration.index, genre_duration.values, color='teal', edgecolor='black', alpha=0.9)
plt.title('Average session duration by content genre', fontsize=14)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Duration', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.4)

plt.show()

# %% [markdown]
# **Завдання 69.** Побудуйте гістограму віку з 20 інтервалами. Колір — `"#02C39A"` (бірюзовий), додайте заголовок.

# %%
# Завдання 69:
plt.figure(figsize=(9,5))
plt.hist(subs['age'], bins=20, color='#02C39A', edgecolor='white', alpha=0.9)

plt.title('Distribution of subscribers by age (20 intervals)', fontsize=14)
plt.xlabel('Age (years)', fontsize=12)
plt.xlabel('Number of subscribers', fontsize=12)

plt.show()

# %% [markdown]
# **Завдання 70.** Побудуйте діаграму кількості сеансів по місяцях. Підписи на осі X поверніть на 45 градусів.
#
# > 💡 `plt.xticks(rotation=45)`.

# %%
# Завдання 70:
month_sess = sess['month'].value_counts().sort_index()

plt.figure(figsize=(10, 5))
plt.bar(month_sess.index, month_sess.values, color='#00A896', edgecolor='black', alpha=0.8)

plt.title('Dynamics of the number of sessions by month', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Session numbers', fontsize=12)

plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# **Завдання 71.** Побудуйте стовпчасту діаграму середнього `monthly_fee` по тарифах. Розмір фігури 8x5. Додайте сітку.
#
# > 💡 `plt.grid(True)`. Сітка для bar-діаграм виглядає краще тільки по осі Y: `plt.grid(axis="y")`.

# %%
# Завдання 71:
tariff_fee = subs.groupby("plan")["monthly_fee"].mean().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
plt.bar(tariff_fee.index, tariff_fee.values, color="coral", edgecolor="black", alpha=0.9)

plt.title("Average monthly fee by tariff", fontsize=14)
plt.xlabel("Tariff plan", fontsize=12)
plt.ylabel("Average fee ($)", fontsize=12)

plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %% [markdown]
# **Завдання 72.** Побудуйте лінійну діаграму кількості сеансів по місяцях. Тип лінії: пунктир, колір червоний, маркери у вигляді крапок.
#
# > 💡 У `plt.plot()` параметри: `linestyle="--"`, `color="red"`, `marker="o"`. Або скорочено: `"r--o"`.

# %%
# Завдання 72:
monthly_sessions = sess["month"].value_counts().sort_index()

plt.figure(figsize=(10, 5))

plt.plot(monthly_sessions.index, monthly_sessions.values, "r--o", linewidth=2, markersize=6)

plt.title("Dynamics of the number of sessions by month", fontsize=14)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Sessions number", fontsize=12)

plt.grid(True, linestyle=":", alpha=0.6)

plt.show()

# %% [markdown]
# **Завдання 73.** Побудуйте scatter plot: вік (X) vs місячна плата (Y). Колір точок зробіть напівпрозорим (`alpha=0.3`).

# %%
# Завдання 73:
plt.figure(figsize=(10, 6))
plt.scatter(subs["age"], subs["monthly_fee"], color="darkcyan", alpha=0.3, edgecolors="none")

plt.title("Subscriber age and monthly interaction", fontsize=14)
plt.xlabel("Age (years)", fontsize=12)
plt.ylabel("Monthly fee ($)", fontsize=12)

plt.grid(True, linestyle="--", alpha=0.5)

plt.show()

# %% [markdown]
# **Завдання 74.** Побудуйте кругову діаграму розподілу підписників за тарифами. Покажіть відсотки на кожному секторі.
#
# > 💡 Параметр `autopct="%1.1f%%"` у `plt.pie()`.

# %%
# Завдання 74:
tariff_counts = subs["plan"].value_counts()

plt.figure(figsize=(6, 6))

plt.pie(
    tariff_counts.values,
    labels=tariff_counts.index,
    autopct="%1.1f%%",
    startangle=140,
    colors=["#02C39A", "#00A896", "#028090"],
    wedgeprops={"edgecolor": "white", "linewidth": 2}
)

plt.title("Distribution of subscribers by tariff plans", fontsize=14, pad=20)

plt.show()

# %% [markdown]
# ## Розділ 2.4. Легенди, кілька серій, subplots (завдання 75-80)
#
# Кілька серій на одному графіку:
# - Кожна серія має параметр `label="..."`
# - Викликаємо `plt.legend()` — показуємо легенду
#
# Кілька графіків поруч (subplots):
# ```python
# fig, axes = plt.subplots(1, 2, figsize=(12, 4))
# axes[0].bar(...)
# axes[0].set_title("Перший")
# axes[1].plot(...)
# axes[1].set_title("Другий")
# plt.show()
# ```

# %% [markdown]
# **Завдання 75.** На одному графіку побудуйте дві лінії: кількість сеансів по місяцях для Smart TV та для Mobile. Додайте легенду з підписами.
#
# > 💡 Двічі викличте `plt.plot(...)` з різними даними, кожен з параметром `label="..."`. Потім `plt.legend()`.

# %%
# Завдання 75:
smart_tv_sess = sess[sess["device"] == "Smart TV"]["month"].value_counts().sort_index()

mobile_sess = sess[sess["device"] == "Mobile"]["month"].value_counts().sort_index()

plt.figure(figsize=(10, 6))

plt.plot(smart_tv_sess.index, smart_tv_sess.values, marker="o", linewidth=2.5, color="royalblue", label="Smart TV")
plt.plot(mobile_sess.index, mobile_sess.values, marker="s", linewidth=2.5, color="crimson", label="Mobile")
plt.title("Number of sessions compared by month: Smart TV vs Mobile", fontsize=14)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Session numbers", fontsize=12)

plt.legend(fontsize=11, loc="upper left")

plt.grid(True, linestyle="--", alpha=0.5)

plt.show()

# %% [markdown]
# **Завдання 76.** На одному графіку побудуйте дві гістограми віку: окремо для чоловіків і жінок (з прозорістю `alpha=0.5` та різними кольорами). Додайте легенду.

# %%
# Завдання 76:
male_age = subs[subs["gender"] == "Ч"]["age"]
female_age = subs[subs["gender"] == "Ж"]["age"]

plt.figure(figsize=(10, 6))

plt.hist(male_age, bins=15, alpha=0.5, color="dodgerblue", edgecolor="blue", label="Чоловіки")
plt.hist(female_age, bins=15, alpha=0.5, color="hotpink", edgecolor="deeppink", label="Жінки")

plt.title("Distribution of subscribers by age and gender", fontsize=14)
plt.xlabel("Age (years)", fontsize=12)
plt.ylabel("Subscribers number", fontsize=12)

plt.legend(fontsize=11)
plt.grid(True, linestyle="--", alpha=0.3)

plt.show()

# %% [markdown]
# **Завдання 77.** Побудуйте дві стовпчасті діаграми поруч через `subplots(1, 2)`:
# - зліва: кількість підписників по країнах
# - справа: кількість підписників по тарифах
#
# Кожній додайте заголовок.

# %%
# Завдання 77:
country_counts = subs["country"].value_counts()
tariff_counts = subs["plan"].value_counts()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.bar(country_counts.index, country_counts.values, color="#00A896", edgecolor="black", alpha=0.8)
ax1.set_title("Numbers of subscribers by country", fontsize=12, fontweight="bold")
ax1.set_xlabel("Country", fontsize=10)
ax1.set_ylabel("Amount", fontsize=10)
ax1.grid(axis="y", linestyle="--", alpha=0.4)

ax2.bar(tariff_counts.index, tariff_counts.values, color="#028090", edgecolor="black", alpha=0.8)
ax2.set_title("Numbers of subscribers by tariff", fontsize=12, fontweight="bold")
ax2.set_xlabel("Tariff", fontsize=10)
ax2.set_ylabel("Amount", fontsize=10)
ax2.grid(axis="y", linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Завдання 78.** Побудуйте 2x2 сітку графіків (`subplots(2, 2)`):
# - (0,0): гістограма віку
# - (0,1): кількість сеансів по жанрах (bar)
# - (1,0): розподіл пристроїв (pie)
# - (1,1): середня тривалість по жанрах (barh)
#
# Кожному додайте заголовок. Розмір фігури — 12x10.
#
# > 💡 `fig, axes = plt.subplots(2, 2, figsize=(12, 10))`. Доступ: `axes[0, 0]`, `axes[0, 1]`, `axes[1, 0]`, `axes[1, 1]`.

# %%
# Завдання 78:
genre_counts = sess["genre"].value_counts()
device_counts = sess["device"].value_counts()
genre_duration = sess.groupby("genre")["duration_min"].mean().sort_values()

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

axes[0, 0].hist(subs["age"], bins=15, color="#02C39A", edgecolor="white", alpha=0.9)
axes[0, 0].set_title("Subscribers age division", fontsize=12, fontweight="bold")
axes[0, 0].set_xlabel("Age (years)")
axes[0, 0].set_ylabel("Number of subscribers")
axes[0, 0].grid(axis="y", linestyle="--", alpha=0.4)

axes[0, 1].bar(genre_counts.index, genre_counts.values, color="royalblue", edgecolor="black", alpha=0.8)
axes[0, 1].set_title("Number of Sessions by Genre", fontsize=12, fontweight="bold")
axes[0, 1].set_xlabel("Genre")
axes[0, 1].set_ylabel("Sessions Count")
axes[0, 1].grid(axis="y", linestyle="--", alpha=0.4)
axes[0, 1].tick_params(axis='x', rotation=45)

axes[1, 0].pie(
    device_counts.values,
    labels=device_counts.index,
    autopct="%1.1f%%",
    startangle=90,
    colors=["#00A896", "#028090", "#F4A261"],
    wedgeprops={"edgecolor": "white", "linewidth": 2}
)
axes[1, 0].set_title("Device Share Distribution", fontsize=12, fontweight="bold")

axes[1, 1].barh(genre_duration.index, genre_duration.values, color="teal", edgecolor="black", alpha=0.9)
axes[1, 1].set_title("Average Session Duration by Genre", fontsize=12, fontweight="bold")
axes[1, 1].set_xlabel("Average Duration (min)")
axes[1, 1].set_ylabel("Genre")
axes[1, 1].grid(axis="x", linestyle="--", alpha=0.4)

plt.tight_layout()

plt.show()

# %% [markdown]
# **Завдання 79.** Побудуйте графік середньої оцінки по жанрах. Стовпці пофарбуйте у РІЗНІ кольори (передайте список кольорів у параметр `color`).
#
# > 💡 `color=["red","blue","green","orange","purple","teal","pink","gray"]` — стільки кольорів, скільки жанрів.

# %%
# Завдання 79:

# %% [markdown]
# **Завдання 80.** Зробіть фінальний дашборд: 2x1 сітка (один графік над іншим), розмір 10x10.
# - зверху: лінійна діаграма кількості сеансів по місяцях, з заголовком "Динаміка переглядів 2024"
# - знизу: горизонтальна стовпчаста діаграма топ-10 жанрів за кількістю сеансів, з заголовком "Топ жанрів"
#
# Після всього — `plt.tight_layout()` (виправляє накладання).
#
# > 💡 `fig, axes = plt.subplots(2, 1, figsize=(10, 10))` + наприкінці `plt.tight_layout()`.

# %%
# Завдання 80:

# %% [markdown]
# ---
#
# # 🎉 Готово!
#
# Якщо ви виконали всі 80 завдань — вітаємо! Ви відпрацювали:
#
# **Pandas (50 завдань):**
# - ✅ `loc` та `iloc` — потужна вибірка за позицією та умовою
# - ✅ Складніший `groupby` з `.agg()`, `.transform()`, групування за кількома стовпцями
# - ✅ `pivot_table` — зведені таблиці у стилі Excel
# - ✅ Робота з датами (`.dt.month`, `.dt.day_name`, різниця дат)
# - ✅ Об'єднання таблиць через `merge`
#
# **Matplotlib (30 завдань):**
# - ✅ Швидкі графіки через pandas `.plot()`
# - ✅ Базові функції matplotlib: `bar`, `plot`, `hist`, `scatter`, `pie`
# - ✅ Налаштування: заголовки, осі, кольори, сітка
# - ✅ Легенди та кілька серій на одному графіку
# - ✅ Subplots — кілька графіків поруч
#
# ### Порада
# Найкращий спосіб запам'ятати — повернутись через тиждень і спробувати найскладніші завдання знову, не підглядаючи. **Так тримати! 🐼📊**
